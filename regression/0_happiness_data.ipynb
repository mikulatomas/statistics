# %%
import seaborn as sns
from datasets import load_happines

# %%
df = load_happines()
df.head()
# Out:
#                      region  economy   family   health  freedom    trust  \
# country
# Switzerland  Western Europe  1.39651  1.34951  0.94143  0.66557  0.41978
# Iceland      Western Europe  1.30232  1.40223  0.94784  0.62877  0.14145
# Denmark      Western Europe  1.32548  1.36058  0.87464  0.64938  0.48357
# Norway       Western Europe  1.45900  1.33095  0.88521  0.66973  0.36503
# Canada        North America  1.32629  1.32261  0.90563  0.63297  0.32957
#
#              generosity  target
# country
# Switzerland     0.29678   7.587
# Iceland         0.43630   7.561
# Denmark         0.34139   7.527
# Norway          0.34699   7.522
# Canada          0.45811   7.427

# %%
sns.pairplot(df, hue='region')

# %%
df.describe()
# Out:
#           economy      family      health     freedom       trust  generosity  \
# count  158.000000  158.000000  158.000000  158.000000  158.000000  158.000000
# mean     0.846137    0.991046    0.630259    0.428615    0.143422    0.237296
# std      0.403121    0.272369    0.247078    0.150693    0.120034    0.126685
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.545808    0.856823    0.439185    0.328330    0.061675    0.150553
# 50%      0.910245    1.029510    0.696705    0.435515    0.107220    0.216130
# 75%      1.158448    1.214405    0.811013    0.549092    0.180255    0.309883
# max      1.690420    1.402230    1.025250    0.669730    0.551910    0.795880
#
#            target
# count  158.000000
# mean     5.375734
# std      1.145010
# min      2.839000
# 25%      4.526000
# 50%      5.232500
# 75%      6.243750
# max      7.587000
