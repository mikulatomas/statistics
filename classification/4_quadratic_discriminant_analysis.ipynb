# %%
from datasets import titanic_data

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

from tools import roc

import plotly.express as px
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
original_X, original_y, train_X, train_y, test_X, test_y = titanic_data()

# %% [markdown]
# ## Drop co-linear features

# %%
original_X = original_X.drop(['embarked_C',
       'embarked_Q', 'embarked_S'], axis=1)

# %% [markdown]
# ## Estimate test error by 5-fold cross validation

# %%
model = QuadraticDiscriminantAnalysis()
cross_val_score(model, original_X, original_y).mean()
# Out:
# 0.7934655702717971

# %% [markdown]
# ## Fit Quadratic Discriminant Analysis

# %%
model = QuadraticDiscriminantAnalysis()
model = model.fit(original_X, original_y)

# %% [markdown]
# ## Confusion matrix and ROC

# %%
tn, fp, fn, tp = confusion_matrix(original_y, model.predict(original_X).ravel()).ravel()

f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}"
# Out:
# 'TP: 235, TN: 484, FP: 65, FN: 107'

# %%
roc(model, original_X, original_y).show()
# Out:
# <div>                            <div id="88bacb98-7c32-4462-b98a-4ee3c32b82e5" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88bacb98-7c32-4462-b98a-4ee3c32b82e5")) {                    Plotly.newPlot(                        "88bacb98-7c32-4462-b98a-4ee3c32b82e5",                        [{"hovertemplate": "False Positive Rate=%{x}<br>True Positive Rate=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": [0.0, 0.0, 0.0, 0.0018214936247723133, 0.0018214936247723133, 0.0036429872495446266, 0.0036429872495446266, 0.01092896174863388, 0.01092896174863388, 0.012750455373406194, 0.012750455373406194, 0.014571948998178506, 0.014571948998178506, 0.01639344262295082, 0.01639344262295082, 0.01639344262295082, 0.01639344262295082, 0.018214936247723135, 0.018214936247723135, 0.020036429872495445, 0.020036429872495445, 0.02185792349726776, 0.023679417122040074, 0.023679417122040074, 0.023679417122040074, 0.023679417122040074, 0.023679417122040074, 0.023679417122040074, 0.023679417122040074, 0.023679417122040074, 0.025500910746812388, 0.025500910746812388, 0.0273224043715847, 0.0273224043715847, 0.029143897996357013, 0.029143897996357013, 0.029143897996357013, 0.029143897996357013, 0.030965391621129327, 0.030965391621129327, 0.03278688524590164, 0.03278688524590164, 0.03460837887067395, 0.03460837887067395, 0.03642987249544627, 0.03642987249544627, 0.03825136612021858, 0.03825136612021858, 0.04007285974499089, 0.04007285974499089, 0.04189435336976321, 0.04189435336976321, 0.04371584699453552, 0.04371584699453552, 0.04553734061930783, 0.04553734061930783, 0.04735883424408015, 0.04735883424408015, 0.04918032786885246, 0.04918032786885246, 0.056466302367941715, 0.056466302367941715, 0.056466302367941715, 0.056466302367941715, 0.060109289617486336, 0.060109289617486336, 0.06375227686703097, 0.06375227686703097, 0.06739526411657559, 0.06739526411657559, 0.0692167577413479, 0.07285974499089254, 0.07650273224043716, 0.07650273224043716, 0.07650273224043716, 0.07832422586520947, 0.07832422586520947, 0.08014571948998178, 0.08014571948998178, 0.08378870673952642, 0.08378870673952642, 0.08561020036429873, 0.08561020036429873, 0.08743169398907104, 0.08743169398907104, 0.09107468123861566, 0.09107468123861566, 0.09107468123861566, 0.09107468123861566, 0.09107468123861566, 0.10018214936247723, 0.10018214936247723, 0.10200364298724955, 0.10200364298724955, 0.10382513661202186, 0.10382513661202186, 0.10746812386156648, 0.10746812386156648, 0.1111111111111111, 0.1111111111111111, 0.11475409836065574, 0.11475409836065574, 0.11657559198542805, 0.11657559198542805, 0.11839708561020036, 0.11839708561020036, 0.122040072859745, 0.122040072859745, 0.12386156648451731, 0.12386156648451731, 0.12568306010928962, 0.12568306010928962, 0.12932604735883424, 0.12932604735883424, 0.13114754098360656, 0.13114754098360656, 0.14207650273224043, 0.14207650273224043, 0.14389799635701275, 0.14389799635701275, 0.14571948998178508, 0.14571948998178508, 0.1493624772313297, 0.1493624772313297, 0.151183970856102, 0.151183970856102, 0.15482695810564662, 0.15482695810564662, 0.15664845173041894, 0.15664845173041894, 0.1621129326047359, 0.1621129326047359, 0.1621129326047359, 0.1657559198542805, 0.1657559198542805, 0.16757741347905283, 0.16757741347905283, 0.16939890710382513, 0.16939890710382513, 0.17486338797814208, 0.17486338797814208, 0.1766848816029144, 0.1766848816029144, 0.18032786885245902, 0.18032786885245902, 0.18397085610200364, 0.18397085610200364, 0.18579234972677597, 0.18579234972677597, 0.1894353369763206, 0.1930783242258652, 0.1930783242258652, 0.1930783242258652, 0.19489981785063754, 0.19489981785063754 ...
