# %%
from datasets import titanic_data

import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from scipy.special import expit
import pandas as pd
import numpy as np

from tools import roc, polynomial_features

import plotly.express as px
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
original_X, original_y, train_X, train_y, test_X, test_y = titanic_data()

# %% [markdown]
# ## Degree 2

# %%
original_X_2 = polynomial_features(original_X, 2)

# %%
original_X_2 = pd.DataFrame(StandardScaler().fit_transform(original_X_2), columns=original_X_2.columns)

# %%
original_X_2.head()
# Out:
#      pclass       sex       age     sibsp     parch      fare  embarked_C  \
# 0  0.827377 -0.737695 -0.565736  0.432793 -0.473674 -0.502445   -0.482043
# 1 -1.566107  1.355574  0.663861  0.432793 -0.473674  0.786845    2.074505
# 2  0.827377  1.355574 -0.258337 -0.474545 -0.473674 -0.488854   -0.482043
# 3 -1.566107  1.355574  0.433312  0.432793 -0.473674  0.420730   -0.482043
# 4  0.827377 -0.737695  0.433312 -0.474545 -0.473674 -0.486337   -0.482043
#
#    embarked_Q  embarked_S  pclass^2     sex^2     age^2   sibsp^2   parch^2  \
# 0   -0.307562    0.615838 -0.371647 -0.737695 -0.393776 -0.182761 -0.226598
# 1   -0.307562   -1.623803  1.711501  1.355574 -0.323902 -0.182761 -0.226598
# 2   -0.307562    0.615838 -0.371647  1.355574 -0.540481 -0.174241 -0.226598
# 3   -0.307562    0.615838  1.711501  1.355574 -0.470394 -0.182761 -0.226598
# 4   -0.307562    0.615838 -0.371647 -0.737695 -0.470394 -0.174241 -0.226598
#
#      fare^2  embarked_C^2  embarked_Q^2  embarked_S^2
# 0 -0.125992     -0.482043     -0.307562     -0.615838
# 1 -0.064192      2.074505     -0.307562      1.623803
# 2 -0.128262     -0.482043     -0.307562     -0.615838
# 3 -0.138706     -0.482043     -0.307562     -0.615838
# 4 -0.128676     -0.482043     -0.307562     -0.615838

# %% [markdown]
# ### Estimate test error by 5-fold cross validation

# %%
model = LogisticRegression(penalty='none')
cross_val_score(model, original_X_2, original_y).mean()
# Out:
# 0.8114493754315486

# %% [markdown]
# ### Confusion matrix and ROC

# %%
model = LogisticRegression(penalty='none')
model = model.fit(original_X_2, original_y)

# %%
tn, fp, fn, tp = confusion_matrix(original_y, model.predict(original_X_2).ravel()).ravel()

f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}"
# Out:
# 'TP: 248, TN: 478, FP: 71, FN: 94'

# %%
roc(model, original_X_2, original_y).show()
# Out:
# <div>                            <div id="bce3e01a-855b-4523-976d-387428402005" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bce3e01a-855b-4523-976d-387428402005")) {                    Plotly.newPlot(                        "bce3e01a-855b-4523-976d-387428402005",                        [{"hovertemplate": "False Positive Rate=%{x}<br>True Positive Rate=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": [0.0, 0.0018214936247723133, 0.0018214936247723133, 0.0018214936247723133, 0.0018214936247723133, 0.
# ## Degree 3

# %%
original_X_3 = polynomial_features(original_X, 3)

# %%
original_X_3 = pd.DataFrame(StandardScaler().fit_transform(original_X_3), columns=original_X_3.columns)

# %%
original_X_3.head()
# Out:
#      pclass       sex       age     sibsp     parch      fare  embarked_C  \
# 0  0.827377 -0.737695 -0.565736  0.432793 -0.473674 -0.502445   -0.482043
# 1 -1.566107  1.355574  0.663861  0.432793 -0.473674  0.786845    2.074505
# 2  0.827377  1.355574 -0.258337 -0.474545 -0.473674 -0.488854   -0.482043
# 3 -1.566107  1.355574  0.433312  0.432793 -0.473674  0.420730   -0.482043
# 4  0.827377 -0.737695  0.433312 -0.474545 -0.473674 -0.486337   -0.482043
#
#    embarked_Q  embarked_S  pclass^2  ...  embarked_S^2  pclass^3     sex^3  \
# 0   -0.307562    0.615838 -0.371647  ...     -0.615838  0.652601 -0.737695
# 1   -0.307562   -1.623803  1.711501  ...      1.623803 -1.752661  1.355574
# 2   -0.307562    0.615838 -0.371647  ...     -0.615838  0.652601  1.355574
# 3   -0.307562    0.615838  1.711501  ...     -0.615838 -1.752661  1.355574
# 4   -0.307562    0.615838 -0.371647  ...     -0.615838  0.652601 -0.737695
#
#       age^3   sibsp^3   parch^3    fare^3  embarked_C^3  embarked_Q^3  \
# 0 -0.138944 -0.127566 -0.148157 -0.092039     -0.482043     -0.307562
# 1 -0.043631 -0.127566 -0.148157 -0.080520      2.074505     -0.307562
# 2 -0.105976 -0.134211 -0.148157 -0.091851     -0.482043     -0.307562
# 3 -0.086134 -0.127566 -0.148157 -0.088262     -0.482043     -0.307562
# 4 -0.086134 -0.134211 -0.148157 -0.091818     -0.482043     -0.307562
#
#    embarked_S^3
# 0      0.615838
# 1     -1.623803
# 2      0.615838
# 3      0.615838
# 4      0.615838
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Estimate test error by 5-fold cross validation

# %%
model = LogisticRegression(penalty='none', max_iter=2000)
cross_val_score(model, original_X_3, original_y).mean()
# Out:
# 0.8013809553700332

# %% [markdown]
# ### Confusion matrix and ROC

# %%
model = LogisticRegression(penalty='none', max_iter=2000)
model = model.fit(original_X_3, original_y)

# %%
tn, fp, fn, tp = confusion_matrix(original_y, model.predict(original_X_3).ravel()).ravel()

f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}"
# Out:
# 'TP: 248, TN: 477, FP: 72, FN: 94'

# %%
roc(model, original_X_3, original_y).show()
# Out:
# <div>                            <div id="e8ee3881-609f-4c30-b81a-e9610a272362" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8ee3881-609f-4c30-b81a-e9610a272362")) {                    Plotly.newPlot(                        "e8ee3881-609f-4c30-b81a-e9610a272362",                        [{"hovertemplate": "False Positive Rate=%{x}<br>True Positive Rate=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": [0.0, 0.0, 0.0, 0.0018214936247723133, 0.0018214936247723133, 0.0018214936247723133, 0.0018214936247723133, 0.